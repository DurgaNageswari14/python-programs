# %% [markdown]
# <a href="https://colab.research.google.com/github/DurgaNageswari14/python-programs/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="apple"
print(len(a))
# Out:
# 5

# %%
x=[10,24,34,35,57,77,80]
print(len(x))
# Out:
# 7

# %%
a=[5,27,19,15,20]
a.sort()
print(a)
# Out:
# [5, 15, 19, 20, 27]

# %%
x=[25,54,57,77,86,8]
x.sort()
print(x)
# Out:
# [8, 25, 54, 57, 77, 86]

# %%
a=[23,99,48,87,24,54]
a.sort(reverse=True)
print(a)
# Out:
# [99, 87, 54, 48, 24, 23]

# %%
x=[23,99,48,87,24,54]
x.sort(reverse=False)
print(x)
# Out:
# [23, 24, 48, 54, 87, 99]

# %%
a=["ram","krishna","durga","nagendra"]
a.sort()
print(a)
# Out:
# ['durga', 'krishna', 'nagendra', 'ram']

# %%
x=[24,44,56]
x.append(50)
print(x)
# Out:
# [24, 44, 56, 50]

# %%
a=["apple","banana","mango"]
a.append("grapes")
print(a)
# Out:
# ['apple', 'banana', 'mango', 'grapes']

# %%
x=[23,44,55,92,0]
x.insert(3,1)
print(x)
# Out:
# [23, 44, 55, 1, 92, 0]

# %%
a=["apple","mango","banana"]
a.insert(0,"cherry")
print(a)
# Out:
# ['cherry', 'apple', 'mango', 'banana']

# %%
x=[22,54,32]
print(x[2])
# Out:
# 32

# %%
a=["apple","guva","mango"]
print(a[1])
# Out:
# guva

# %%
x=[34,54,66]
a=[42,54,85]
print(a+x)
# Out:
# [42, 54, 85, 34, 54, 66]

# %%
print(x+a)
# Out:
# [34, 54, 66, 42, 54, 85]

# %%
a=[34,47,56,63,93]
a.remove(63)
print(a)
# Out:
# [34, 47, 56, 93]

# %%
x=["cockroach","honeybee","wasp"]
x.remove("honeybee")
print(x)
# Out:
# ['cockroach', 'wasp']

# %%
a=[199,353,765,876]
a.pop(3)
print(a)
# Out:
# [199, 353, 765]

# %%
x=["elephant","ant","dog","lion"]
x.pop()
print(x)
# Out:
# ['elephant', 'ant', 'dog']
