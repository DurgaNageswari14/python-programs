# %% [markdown]
# <a href="https://colab.research.google.com/github/DurgaNageswari14/python-programs/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day1 Basic Python Programs

# %%
a=12
b=23
c=27
print(a+b)
print(a-b)
print(a*b)
# Out:
# 35
# -11
# 276

# %% [markdown]
# Day2 Variables And DataTypes

# %% [markdown]
# Variables

# %%
name="durga"
age=23
print(name)
print(age)
# Out:
# durga
# 23

# %% [markdown]
# **Data** ***Types***

# %% [markdown]
# i Int

# %%
age = 23
print(age)
type(age)
# Out:
# 23
# int

# %% [markdown]
# iifloat

# %%
height = 5.7
print(height)
type(height)
# Out:
# 5.7
# float

# %% [markdown]
# String

# %%
name = "Durga"
print(name)
type(name)
# Out:
# Durga
# str

# %% [markdown]
# Boolen

# %%
age = 20
print(age >= 18)
type(age)
# Out:
# True
# int

# %% [markdown]
# Printing function

# %%
print("Data Analytics")
# Out:
# Data Analytics

# %% [markdown]
# Type checking

# %%
age = 23

print(type(age))
# Out:
# <class 'int'>

# %%
height = 5.7

print(type(height))
# Out:
# <class 'float'>

# %%
name = "Durga"

print(type(name))
# Out:
# <class 'str'>

# %%
age = 20
print(age >= 18)
print(type(age))
# Out:
# True
# <class 'int'>

# %% [markdown]
# Day3 Operators

# %% [markdown]
# Operators

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Floor Division:", a // b)
print("Power:", a ** b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# Floor Division: 2
# Power: 100000

# %% [markdown]
# captalized

# %%
name = "durga"

result = name.capitalize()

print(result)
# Out:
# Durga

# %%
name="durga"
name.upper ()
# Out:
# 'DURGA'

# %%
name.lower()
# Out:
# 'durga'

# %% [markdown]
# Swape case

# %%
surname="KUnapAREddi"
name="DuRGa"
print(surname.swapcase())
name.swapcase()
# Out:
# kuNAPareDDI
# 'dUrgA'

# %% [markdown]
# Split

# %%
name="my name is"
name.split()
# Out:
# ['my', 'name', 'is']

# %%
mail="durga11@gmail.com"
mail.split()
# Out:
# ['durga11@gmail.com']

# %% [markdown]
# # Day4 Conditional Statements

# %% [markdown]
# IF

# %%
age = 20

if age >= 18:
    print("Eligible to vote")
# Out:
# Eligible to vote

# %% [markdown]
# IF ELSE

# %%
a=22345
b=19456
if a>b:
  print("a is greater")
  #print("In True block")
  c=a+b
  print(c)
else:
  print('b is greater')
  #print("In False block")
  c=a*b
  print(c)
# Out:
# a is greater
# 41801

# %%
age = 20

if age>= 18:
    print("Eligible to vote")
else:
     print("notEligible to vote")
# Out:
# Eligible to vote

# %% [markdown]
# Loops

# %%
for i in range(65, 100,5):
    print(i)
# Out:
# 65
# 70
# 75
# 80
# 85
# 90
# 95

# %%
for i in range(50, 100,2):
    print(i)
# Out:
# 50
# 52
# 54
# 56
# 58
# 60
# 62
# 64
# 66
# 68
# 70
# 72
# 74
# 76
# 78
# 80
# 82
# 84
# 86
# 88
# 90
# 92
# 94
# 96
# 98

# %%
for i in range(0, 6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
colors = ["Red", "Blue", "Green"]

for color in colors:
    print(color)
# Out:
# Red
# Blue
# Green
